# %% [markdown]
# W4A2

# %%
n = int(input())
while(n<= 0 ):
    n= int(input())
if n < 2:
    pass 
else:
    cnt= 0 
    for i in range(2, int(n**0.5) + 1):
        if n%1==0:
            print(f"{n} la so nguyen to")
            break
        else:
            print(f"{n} la hop so")
# Out:
# 13 la so nguyen to

# %% [markdown]
# W4A16

# %%
print("Các số chẵn chia hết cho 3")
for i in range(100):
    if i % 2== 0 and i % 3 == 0:
        print(i,end= " ")
# Out:
# Các số chẵn chia hết cho 3
# 0 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %% [markdown]
# W4A17

# %%
a= int(input())
print(f"Bảng của cửu chương của {a}")
for i in range(1,11):
    ket_qua= a*i
    print(f"{a}x{i}= {ket_qua}")
# Out:
# Bảng của cửu chương của 6
# 6x1= 6
# 6x2= 12
# 6x3= 18
# 6x4= 24
# 6x5= 30
# 6x6= 36
# 6x7= 42
# 6x8= 48
# 6x9= 54
# 6x10= 60

# %% [markdown]
# W4A18

# %%
a= int(input())
b= int(input())
print('Ước chung của {a}và {b}:')
lm= min(a,b)
for i in range(1, lm +1):
    if a % i == 0 and b % i ==0:
        print(i, end=" ")
# Out:
# Ước chung của {a}và {b}:
# 1 5

# %% [markdown]
# W4A19

# %%
print("các số dương chẵn nhỏ hơn hoặc bằng 1000:")
for i in range (2,1000):
    if i % 2 == 0:
        print(i, end= " ")
# Out:
# các số dương chẵn nhỏ hơn hoặc bằng 1000:
# ...

# %% [markdown]
# W4A20(chưa hiểu)

# %%
n = int(input())
if n>= 0 and (n,(n-1))== 0:
    print(f'{n} là số dạng 2^k')
else:
    print(f'{n} không có dạng 2^k')
# Out:
# 8 không có dạng 2^k

# %% [markdown]
# W4A21

# %%
n = int(input())
print("Tổng các chữ số của n :")
tong= ((n+1)*n)/2
print(tong)
# Out:
# Tổng các chữ số của n :
# 28.0

# %% [markdown]
# W4A22

# %%
# Out:
#   Cell In[20], line 5
#     print(f"{a} và {b}:")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %% [markdown]
# W4A23

# %%
n = int(input())
tong = 0 
k = 0
while tong + (k + 1) < n :
    k += 1
    tong += k 
    print(f'Số lớn nhất để tổng < {n} là: {k}')
    print(f'Khi đó tổng S({k}) = {tong}')
# Out:
# Số lớn nhất để tổng < 6 là: 1
# Khi đó tổng S(1) = 1
# Số lớn nhất để tổng < 6 là: 2
# Khi đó tổng S(2) = 3
