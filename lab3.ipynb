# %%
1

# %%
x= int(input())
y= 2 * x
print(y)
# Out:
# 6

# %% [markdown]
# 2

# %%
a= int(input())
b= int(input())
dien_tich_hcn= a*b
ban_kinh= a/2
dien_tich_tron= 3.14*(ban_kinh**2)
Dien_tich_con_lai= dien_tich_hcn - dien_tich_tron
print(f'Diện tích còn lại:{Dien_tich_con_lai:.2f}')
# Out:
# Diện tích còn lại:4.93

# %% [markdown]
# 5

# %%
A = input()
thuong_tuong_ung= A.lower()
ma_so_lien_truoc= ord(thuong_tuong_ung)-1
lien_truoc= chr(ma_so_lien_truoc)
print(f"Kí tự thường liền trước :'{thuong_tuong_ung}'la:'{lien_truoc}'")
# Out:
# Kí tự thường liền trước :'5'la:'4'

# %% [markdown]
# W3A3

# %%
n = int(input("Nhap vao mot so nguyen:"))
if n > 0 and (n & (n-1)) == 0:
    print(f"{n} la luy thua cua 2.")
else:
    print(f"{n} khong phải là lũy thua cua 2.")
# Out:
# 3 khong phải là lũy thua cua 2.

# %%
a= 50
b= 50.0 
c= 100 - 50j
print("Kieu du lieu cua a", type(c))
# Out:
# Kieu du lieu cua a <class 'complex'>

# %%
a =10 
b =20 
chuvi = 2*(a+b)
print('Chu vi là:' '%.2f' % chuvi)
# Out:
# Chu vi là:60.00
