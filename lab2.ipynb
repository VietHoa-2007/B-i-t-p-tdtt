# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# W2A2

# %%
name = input("Nhap ten cau ban")
print(f'Hello {name}')
# Out:
# Hello Hoa

# %% [markdown]
# W2A3

# %%
a = int(input())
b = int(input())
print(f'Tong cua {a} va {b} la: {a + b}')
print(f'Hieu cua {a} va {b} la: {a - b}')
print(f'Tich cua {a} va {b} la: {a * b}')
print(f'Phan nguyen cua {a} va {b} la: {a // b}')
print(f'Phan du cua {a} va {b} la: {a % b}')
print(f'Ket qua chia thuc cua {a} va {b} la: {a / b:.2f}')
# Out:
# Tong cua 2 va 3 la: 5
# Hieu cua 2 va 3 la: -1
# Tich cua 2 va 3 la: 6
# Phan nguyen cua 2 va 3 la: 0
# Phan du cua 2 va 3 la: 2
# Ket qua chia thuc cua 2 va 3 la: 0.67

# %% [markdown]
# W2A4

# %%
a1 = int(input())
b1 = int(input())
c1 = int(input())
a2 = int(input())
b2 = int(input())
a3 = int(input())
#a1, b1, c1, a2, b2, a3 = map(int, input("Nhap vao 6 dau diem: ").split(" "))
TB = ((a1+b1+c1) + (a2+b2)*2 + a3*3) / 10
print(f"{TB:.1f}")
# Out:
# 14.4

# %% [markdown]
# W2A5

# %%
a, b = map(int, input().split())
ket_qua = a ** b 
print(ket_qua)
# Out:
# 8

# %% [markdown]
# W2A6

# %%
a = input()
print(ord(a))
ki_tu_hoa = chr(ord(a)-32)
print(ki_tu_hoa)
# Out:
# 52

# %% [markdown]
# W2A7

# %%
A = ((13 ** 2) * 3) + 5
B = 13 ** 2 * 3 + 5
print(A, B, sep=" vs ")
# Out:
# 512 vs 512

# %% [markdown]
# W2A8

# %%
c= int(input())
F = 9/5*c + 32
print(f'{F:.2f}')
# Out:
# 41.00

# %% [markdown]
# W2A9

# %%
x = float(input())
y = (x + 10)*(1 + 0.1 + 0.3)
print(f'{y:.2f}')
# Out:
# 21.00

# %% [markdown]
# W2A10

# %%
x, y, z = input().split()
print(f"Hi {z}, {y} and {x}")
# Out:
# Hi X, Y and H

# %% [markdown]
# W2A11

# %%
h = int(input("Nhập số giờ (h): "))
m = int(input("Nhập số phút (m):"))
tong_giay = h * 3600 + m * 60
print(tong_giay)
# Out:
# 18240

# %% [markdown]
# W2A12

# %%
n = int(input("Nhập độ dài cạnh n: "))
so_mieng_dan = 6 * (n ** 2)
print(so_mieng_dan)
# Out:
# 150

# %% [markdown]
# W2A13

# %%
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
tich = a * b
hang_don_vi = tich % 10
print(hang_don_vi)
# Out:
# 4

# %% [markdown]
# W2A14

# %%
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a,b = b,a
print(f"Sau khi đổi:a={a},b={b}")
# Out:
# Sau khi đổi:a=5,b=4

# %% [markdown]
# W2A15

# %%
n = int(input("Nhập n: "))
so_sao = 6 * n * (n-1) + 1
print(so_sao)
# Out:
# 121

# %% [markdown]
# W2A16

# %%
print("Summer")
print("Spring")
print("Autumn")
print("Uwinter")
# Out:
# Summer
# Spring
# Autumn
# Uwinter

# %% [markdown]
# W2A17

# %%
print(" * ")
print(" *** ")
print(" ***** ")
# Out:
#  *
#  ***
#  *****

# %% [markdown]
# W2A18
